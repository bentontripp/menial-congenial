# %% [markdown]
# ## Table of Contents
#
# 1. <a href="#section1">Introduction</a>
# 2. <a href="#section2">Limits, Derivatives, & Integrals</a>
# 3. <a href="#section3">Series</a>
# 4. <a href="#section4">Parametric Equations & Polar Coordinates</a>
# 5. <a href="#section5">Vectors & Vector Calculus</a>

# %% [markdown]
# <a id="section1"></a>

# %% [markdown]
# # 1 - Introduction
# _______________________
#
# I distinctly remember my very first math class as an undergrad. I was majoring in Mechanical Engineering with no background in Computer Science or any form of programming. I was a bit of a math wiz growing up, but to be honest, I very naively thought that I could get away with just coasting through school and a career without worrying about developing any real computer skills. However, after introducing the Calc 2 course that first day, my professor acknowledged that the school had recently invested in campus-wide access to [MATLAB]( https://www.mathworks.com/products/matlab.html). He explained that learning how to use it would not only be helpful as a resource to check homework answers, but also a game-changer for any students hoping for a career in engineering. This sparked my interest, and eventually led me to altogether change my degree to Applied Mathematics and Computer Science. Now, I have a career as a Data Scientist.
#
# My point isn't that every student taking a college math class needs to learn MATLAB. However, looking back I wish I could have understood that the real power of mathematics doesn't come with a paper and pencil. Computers are unbelievably powerful machines, capable of solving problems with speed and precision impossible to any person. Of course, this doesn't mean that people do not need to learn math. The potential of mathematics is reached when a person who understands the principles and theories combines their knowledge with the capabilities of modern computers. This is where education systems often fall short - they exclusively teach math without teaching students how to apply their knowledge programmatically.
#
# ### **The Purpose of this Blog**
#
# The purpose of this blog is not to teach programming. There are already countless resources readily available for those that are genuinely interested in learning to program. Instead, this blog is meant for students who want to use computers to help them with their math homework. This is how I was first introduced to programming. When I began, I didn't really understand what was actually happening in the background. But by simply typing out the problem I could make sure that my work was correct. To me, this was a priceless resource. Furthermore, it was what inspired me to seek out a deeper understanding of computer science and actually apply the math that I was learning. I hope that by writing this blog, I not only help students to get the correct answers on their assignments, but also inspire them to dig deeper.
#
# My blog is also not meant to teach math, although some principles might be explained briefly. Rather, it is meant to teach students how to use programming to solve math problems. I will primarliy be focusing my content on solving calculus problems. However, mathematics is one of those things that builds upon prior knowledge. For students studying Algebra or Trigonometry, I am sure that some of my blogposts will cover many of the concepts taught in those courses.
#
# ### **Introduction to Python and Sympy**
#
# Although many programming languages exist, one of the most popular for scientific programming is [Python](https://wiki.python.org/moin/BeginnersGuide/Overview). One of the greatest benefits of Python is that it is all Open-Source, meaning that it is free to use. Furthermore, anyone can create add-on libraries that are free to install. Throughout my blog, I will primarily be relying on a Python package called [SymPy](https://www.sympy.org/en/index.html). For each article, I will give an explanation of what I am doing. But it will be easiest if I start out this blog series with an introduction to Python and SymPy, since I am assuming that my readers have little or no background in programming.
#
# Python can either be run locally on your computer or on the cloud. If you are running Python locally, I recommend using [Anaconda](https://docs.anaconda.com/anaconda/install/index.html). However, the easiest solution - especially for a beginner - would be to use a cloud-based platform. [Google Colab](https://research.google.com/colaboratory/faq.html), a free cloud-based platform hosted by Google. It is formatted as a "Notebook", which is basically a more user-friendly view for coding in Python. Colab Notebooks are saved in Google Drive, so the only requirement is that you first obtain a Google Account. To create a new Colab Notebook or to view some of the examples provided by Google, click on the following link:
#
# [https://colab.research.google.com/?utm_source=scs-index](https://colab.research.google.com/?utm_source=scs-index)
#
# Within your notebook, you can add individual "cells". Each of the code cells can be executed separately by either clicking the "play" button, or by pressing **CTRL**+**ENTER** / **CMD**+**ENTER** and display each of their respective results below them. There are also text cells available for titles, notes, etc. Additional cells can easily be inserted using the *+Code* or *+Text* buttons at the top.
#
# To begin, we will need to import any additional libraries that will be used. In our case, that's only the SymPy library. Importing a library in python is pretty straight-forwarward. You simply need to use the `import` command. In general, libraries come with multiple functions/methods that can be imported individually. This is typically good practice. But in our case we are just going to import the full functionality of the SymPy library. This is done with by running `from sympy import *`.

# %%
from sympy import *

# %% [markdown]
# From here, it isn't too difficult. To create variables, you use what are referred to in SymPy as `symbols`. As an example, let's say you want to use the variable $x$ in your equation. First, you must create $x$ as a variable. This is done with the following line of code:

# %%
# create a variable "x"
x = symbols('x')

# %% [markdown]
# The first thing I would like to note is the first line of code, `# create a variable "x"`. This line is not necessary, just used as a "comment" for whomever is reading the code. Any line beginning with `#` in Python is considered a comment. A comment is often used a reference to explain what a section of code is doing.
#
# The second line is the important one: `x = symbols('x')`. If you recall, I mentioned that SymPy uses `symbols` as a function to define variables. In this line, it is declared that $x$ is a symbol, denoted by the `'x'` argument within the `symbol` function's brackets. `'x'` is what is referred to in the "computer world" as a *string*, or a data-type denoted by Unicode characters. If that's confusing to you, no need to worry. In less tech-savvy terms, a string is literally just some data stored in a "string" of characters. Anything within quotes in pyton is considered a string (they can be single or double quotes).
#
# To recap, to create a variable we need to *declare* what it will be. It doesn't need to be $x$, it can be almost anything. Let's try using *y* instead:

# %%
y = symbols('y')
print(y)
# Out:
# y

# %% [markdown]
# This time, I added an extra line of code: `print(y)`. What is this for? Well you might have noticed that after running this cell, it literally "printed" $y$. The `print()` function is used to display whatever argument is put inside of its brackets. In this case, we created the variable (symbol) `y`, and then printed it.
#
# Now, to simplify things I will show how to create multiple variables in just one line of code:

# %%
# create multiple variables
a, b, c = symbols('a b c')

# %% [markdown]
# Notice that each of the declared variables are separated by a comma, and the variables listed within the string (the parameter for the `symbols()` function) are separated by a space. As long as this syntax is followed (with the variable names and order matching), you can create as many variables as you need!
#
# For a shortcut to create some of the most common symbols used (i.e. $x$, $y$, $z$, $t$, etc.), simply use the `init_session()` function at the beginning of your session. It will `import *`, create common symbols, and call `init_printing()`.

# %%
# to create basic symbols and common functionality (to hide the dialogue, use the argument "quiet=True")
init_session()
# Out:
# IPython console for SymPy 1.8 (Python 3.9.7-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.8/

# %% [markdown]
# `init_printing()` lets you print out your python code in actual mathematical notation. It is not necessarily something you need, but can be helpful at times depending on what you need. I have created a simple example below:

# %%
# latex print after "init_printing()" is initiated using init_session()

Integral((1/x)**3, x)
# Out:
# ⌠
# ⎮ 1
# ⎮ ── dx
# ⎮  3
# ⎮ x
# ⌡

# %% [markdown]
# Moving forward, assume that each new script includes both `from sympy import *` and `init_session()` at the beginning.
#
# From here, creating, solving, and plotting actual equations is pretty straight-forward. Before jumping into any actual calculus, I will give a brief demonstration of plotting with SymPy. Then, I will just explain any other new concepts as they come up.
#
# ### **Plotting in Sympy**
# One of the biggest challenges in math, especially as it becomes more and more complex, is visualizing what is going on. With that being said, I thought it would be helpful to do one more "introductory" article before diving into some real math. Again, some of these things will be expounded upon later on, but I wanted to at least give some background on how to plot so that it I don't have to explain it too deeply later on.
#
# To plot you will be using the `plotting.plot()` function. By default, SymPy plots use the `matplotlib` library - one of them most popular Python plotting libraries - in the backend. But SymPy plotting is set up so that it is easy to integrate (no pun intended) calculus problems. If you are coding in a notebook, I would recommend using the `%matplotlib inline` [magic](https://ipython.readthedocs.io/en/stable/interactive/tutorial.html#magics-explained) function at the beginning of your script to automatically print the plot in the notebook.
#
# When calling the function, simply put the calculation that you wish to plot into the paranthases. We will also include the `line_color` argument to specify the color:

# %%
# %matplotlib inline

p1 = plotting.plot(3 + 2*x, line_color='red', show=True)
p2 = plotting.plot(2*x**2 - 20, line_color='blue', show=True)

# %% [markdown]
# To combine two plots into one, just use the `extend` method as follows:

# %%
p1.extend(p2)
p1.show()

# %% [markdown]
# 3D plotting is a little more complex. Instead of calling `plotting.plot()`, instead call the `plotting.plot3d()` function. In addition to the calculation to be plotted, it is also necessary to specify the $x$ and $y$ limits of the plot. This is done through tuples of the following format: <br>
#
# `(variable, variable minimum, variable maximum)`

# %%
p3 = plotting.plot3d(2*x**2 + 3*y**2, (x, -5, 5), (y, -5, 5))

# %% [markdown]
# *Full SymPy Tutorial:* [https://docs.sympy.org/latest/tutorial/index.html](https://docs.sympy.org/latest/tutorial/index.html) <br>
#
# *Addional documentation can be found at the official SymPy website:* [https://docs.sympy.org/latest/modules/plotting.html](https://docs.sympy.org/latest/modules/plotting.html) <br>

# %% [markdown]
# <a id="section2"></a>

# %% [markdown]
# # 2 - Limits, Derivatives, & Integrals
# _______________________
#
# ### **Limits**
#
# Sympy comes with its own `limit` function, which makes computing limits pretty straightforward. I will print out a series of limit problems, and then demonstrate how to use sympy to solve each of them: <br>
#
# **a.** $\lim_{x \to 3} f(x)$ where $f(x) = x^2$ <br>
#
# **b.** $\lim_{x \to 0} g(x)$ where $g(x) = \frac{\lvert x \rvert }{x}$ <br>
#
# **c.** $\lim_{x \to +\infty} h(x)$ where $h(x) = \frac{(x + 1)^3}{(x - 1)}$ <br>

# %%
f_x = x**2
g_x = Abs(x)/x
h_x = x**3 + 2*x**2

plot_a = plotting.plot(f_x, line_color='red')
plot_b = plotting.plot(g_x, line_color='blue')
plot_c = plotting.plot(h_x, line_color='green')

# %% [markdown]
# To solve $\lim_{x \to 3} f(x)$, use the sympy `limit` function using the following format/parameters:
#
# `limit(function, symbol, limit)`

# %%
limit(f_x, x, 3)
# Out:
# 9

# %% [markdown]
# Easy! Unfortunately, SymPy calculates limits using a series expansion. Because this is only an approximation, functions that contain discontinuities or domain constraints are often calculated incorrectly. For example, the limit as $g(x)$ approaches zero has no solution. However, Sympy approximates the limit to be either 1 or -1:

# %%
limit(g_x, x, 0)
# Out:
# 1

# %% [markdown]
# Luckily, [workarounds](https://medium.com/swlh/fixing-sympys-limit-calculation-flaws-5b46440f97c1) exist that make taking limits of this nature doable. Creating a custom [function](https://docs.python.org/3/tutorial/controlflow.html#defining-functions) that takes the limit at points close to the original "approaching" point makes this a simple process.

# %%
def lim(func, variable, approaching, approachFrom='None'):
    """
    Custom limit function that handles discontinuities
    param func: function that you are taking the limit of
    param variable: variable in the function
    param approaching: the number your are approaching in the limit
    param approachFrom: direction approaching from; either "-", "+", or "None"
    """
    # If the `approachFrom` direction is negative:
    if approachFrom=='-':
        # substitute the original `approaching` parameter with a number slightly to the left
        if func.subs(variable, approaching - 1e-6).is_real: 
            return sympy.limit(func, variable, approaching, approachFrom)
        else:
            print('Limit does not exist')
    # If the `approachFrom` direction is positive:
    elif approachFrom == '+':
        # substitute the original `approaching` parameter with a number slightly to the right
        if func.subs(variable, approaching + 1e-6).is_real:
            return sumpy.limit(func, variable, approaching, approachFrom)
        else:
            print('Limit does not exist')
    # If the `approachFrom` direction is neither, test both and subtruct:
    else:
        # substitute the original `approaching` parameter with a number slightly to the left and to the right, then subtract
        leftApprox = func.subs(variable, approaching - 1e-6)
        rightApprox = func.subs(variable, approaching + 1e-6)
        if Abs(leftApprox-rightApprox) < 0.1:
            return sympy.limit(func, variable, approaching)
        else:
            print('Limit does not exist')

lim(g_x, x, 0)
# Out:
# Limit does not exist

# %% [markdown]
# If the limit is infinity, this can easily be specified using double "o". Evaluating the limit on only one side can also be done through an additional argument `'+'` or `'-'`:

# %%
lim(h_x, x, oo, '+')
# Out:
# Limit does not exist

# %% [markdown]
# ### **Derivatives**
#
# Differentiating with SymPy is can be accomplished using the `diff()` function. Like we have done in prior posts, I will demonstrate through several examples: <br>
#
# **a.** For $f(x)=3x^2-4x+1$, find $f'(3)$ <br>
#
# **b.** For $g(x)=\ln(\frac{x^2}{2x + 1})$, find $g''(1)$ <br>
#
# **c.** For $h(x, y)=y^3x^2$, find $\frac{\partial h}{\partial x}(1, 2)$ <br>
#
# **d.** For the same h(x, y), find $\frac{\partial x}{\partial y}(1, 2)$ <br>
#
# **e.** For the same h(x, y), find $\frac{\partial^2 x}{\partial^3 y}(1, 2)$

# %%
f_x = 3*x**2 - 4*x + 1
g_x = ln(x**2 / (2*x + 1))
h_x = y**3 * x**2

p1 = plotting.plot(f_x, line_color='blue')
p2 = plotting.plot(g_x, line_color='red')
p3 = plotting.plot3d(h_x)

# %% [markdown]
# Differentiating an equation is done through the `diff()` function as follows:

# %%
# Differentiate f(x) with respect to x
diff(f_x, x)
# Out:
# 6⋅x - 4

# %% [markdown]
# To evaluate, substitue the number in for the variable using the `subs` method:

# %%
# Differentiate f(x) with respect to x, where x = 2
diff(f_x, x).subs(x, 2)
# Out:
# 8

# %% [markdown]
# Notice that problem **b** is a derivative of the second order. To solve this, an additional argument `2` is added to the `diff()` function after the variable $x$:

# %%
diff(g_x, x, 2).subs(x, 1)
# Out:
# -14/9

# %% [markdown]
# Partial derivatives such as those in problem **c** are not too different from the prior examples. Simply differentiate with respect to $x$, and substitute for both $x$ and $y$ when evaluating using the `subs` method:

# %%
diff(h_x, x).subs(x, 1).subs(y, 2)
# Out:
# 16

# %% [markdown]
# Multi-Variate Differentiation is also similar, but this time differentiate with respect to x and y:

# %%
diff(h_x, x, y).subs(x, 1).subs(y, 2)
# Out:
# 24

# %% [markdown]
# For higher orders of differentiation, the order for each variable can be specified as an argument following each of the respective variables in the `diff()` function:

# %%
diff(h_x, x, 2, y, 3).subs(x, 1).subs(y, 2)
# Out:
# 12

# %% [markdown]
# ### **Integrals**
#
# Integrating with SymPy is done through the `integrate()` function with the expression as the first argument, and a tuple as the second argument that matches the following format: <br>
# (`integration_variable`, `lower_limit`, `upper_limit`)
#
# The following problems will be used as examples:
#
# **a.** Given $f(x)=x^3 - 2x^2 + 4x$, find $\int_{-1}^{1} f(x) \,dx$ <br>
#
# **b.** For the same $f(x)$, find $\int_{-\infty}^{0} f(x) \,dx$ <br>
#
# **c.** Given $g(x, y)=3x^2 + y^2$, find $\iint_D g(x, y) \,dA$ where {$(x,y)| -2 \leq y \leq 3, y^2 - 3 \leq x \leq y + 3$} <br>

# %%
f_x = x**3 - 2*x**2 + 4*x
integrate(f_x, (x, -1, 1))
# Out:
# -4/3

# %% [markdown]
# If the upper/lower limit is infinity, this can easily be specified using double "o" as follows:

# %%
integrate(f_x, (x, -oo, 0))
# Out:
# -∞

# %% [markdown]
# Problem **c** $\iint_D 3x^2 + y^2 \,dA$ where {$(x,y)| -2 \leq y \leq 3, y^2 - 3 \leq x \leq y + 3$} can also be written as: <br>
#
# $\int_{y=-2}^{y=3}\int_{x=y^2-3}^{x=y^2+3} 3x^2 + y^2 \,dx \,dy$ <br>
#
# When solving this in SymPy, the outer-most integral is the last argument, and the innermost is the second argument (following the original expression). The same pattern continues for triple integrals.

# %%
g_x = 3*x**2 + y**2
integrate(g_x, (x, y**2 -3, y + 3), (y, -2, 3))
# Out:
# 2375/7

# %% [markdown]
# *Addional documentation can be found at the official SymPy website:* <br>
# [https://docs.sympy.org/latest/tutorial/calculus.html#limits](https://docs.sympy.org/latest/tutorial/calculus.html#limits) <br>
# [https://docs.sympy.org/latest/tutorial/calculus.html#derivatives](https://docs.sympy.org/latest/tutorial/calculus.html#derivatives) <br>
# [https://docs.sympy.org/latest/tutorial/calculus.html#integrals](https://docs.sympy.org/latest/tutorial/calculus.html#integrals) <br>

# %% [markdown]
# <a id="section3"></a>

# %% [markdown]
# # Series
# _______________________
#
# ### Series Expansion
#
# Computing a series expansion using SymPy is pretty straightforward. Consider the following equation:
#
# $f(x) = \frac{1}{x + 1}$
#
# And recall that $\lim_{x\to 0} f(x)  = \infty$

# %%
f_x = 1 / (x + 1)
plt = plotting.plot(f_x, line_color='red')

# %% [markdown]
# The series expansion can be caluculated using the SymPy `series` method, where the parameters are as follows:
# 1) variable
# 2) lower limit
# 3) upper limit
#
# For example, consider the series expansion of $f(x)$. By default, the `series` method computes the expansion around the point $x = x_0$ and order $x^n$, with the arguments `x0=0` and `n=6`.

# %%
f_x.series(x)
# Out:
#          2    3    4    5    ⎛ 6⎞
# 1 - x + x  - x  + x  - x  + O⎝x ⎠

# %% [markdown]
# To remove the Landau order term, use the `removeO` method:

# %%
f_x.series(x).removeO()
# Out:
#    5    4    3    2
# - x  + x  - x  + x  - x + 1

# %% [markdown]
# The limit points and order can also be updated:

# %%
f_x.series(x, x0=1, n=3).removeO()
# Out:
#              2
#   x   (x - 1)    3
# - ─ + ──────── + ─
#   4      8       4

# %% [markdown]
# ### Convergence Testing
#
# A common problem in calculus is testing whether a series is convergent (and absolutely convergent) or divergent. SymPy has methods to conduct these tests: `is_comvergent` and `is_absolutely_convergent`.
#
# Consider the following series:
#
# $g(x) = \sum_{n=1}^{\infty} \frac{1}{(n+1)(n+2)}$
#
# To write this expression using SymPy, you can use the `Sum()` function, with the expression as the first argument and a tuple in the following format as the second:
# `(variable, start, end)`
#
# Then, use the `is_convergent` and `is_absolutely_convergent` methods.

# %%
g_x = 1 / ((n + 1) * (n + 2))

print(Sum(g_x, (n, 1, oo)).is_convergent())
print(Sum(g_x, (n, 1, oo)).is_absolutely_convergent())
# Out:
# True
# True

# %% [markdown]
# *Addional documentation can be found at the official SymPy website:* <br>
# [https://docs.sympy.org/latest/tutorial/calculus.html#series-expansion](https://docs.sympy.org/latest/tutorial/calculus.html#series-expansion) <br>
# [https://docs.sympy.org/latest/modules/concrete.html#concrete-class-reference](https://docs.sympy.org/latest/modules/concrete.html#concrete-class-reference)

# %% [markdown]
# <a id="section4"></a>

# %% [markdown]
# # 4 - Parametric Equations & Polar Coordinates
# _______________________

# %% [markdown]
# <a id="section5"></a>

# %% [markdown]
# # 5 - Vectors & Vector Calculus
# _______________________
